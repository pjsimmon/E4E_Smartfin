# %%
#Purisa Jasmine Simmons
#July 12, 2018
#Estimating wave statistics from IMU data.
#Version 1: Focuses on data collected from accelerometer.
#Using this paper as a guide: http://essay.utwente.nl/59198/1/scriptie_J_Kuperus.pdf

#Overview of Algorithm:
#1. Create two arrays: time_list has time offsets and acc_list has accelerations.
#2. Find local maximums and local minimums, using a threshold.
#3. Estimate wave height via double integration of acceleration between
#   a peak and the subsequent valley.
#4. Return the average wave height for that surf session. 
#5. Return the average wave frequency.  


#Data Units:
#acceleration is measured in g, 500a = 1g = -9.81m/s^2
#velocity measured in m/s
#distance measured in m
#time measured in seconds

# %matplotlib inline


import math
import re

#Need to do peak-picking before algorithm runs:
#1. Read through file, save all times and accelerations:
print('Running WaveStats Algorithm:')

#Reading data from filename_r
filename_r = "Motion_14644.CSV"
read_file = open(filename_r, "r")

#File that gets written to:
write_file = open("WaveStatsOut.txt", "w")

#Initialize lists
t1 = 0 
t2 = 0
time_list = []  #list of time offsets; t_out = current_time - prev_time 
acc_list = []   #list of estimated accelerations

with open(filename_r, 'r') as f: 
  for line in f:
    #print line     #helps with debugging
    str_array = line.split(',')  #separates each line into an array on commas

    #-------Calculating Time Offset--------#
    if str_array[0] == "UTC":
      t1 = 0
      t2 = 0
      time_list.append(0)  #initialize time_list with 0

    else:
      t2 = str_array[0]

      if (t2 != 0 and t1 != 0 and str_array[2] != "N/A"):
        time_regex = r"(\.\d+)" #regex to get the part of time that we care about
        t2_val = float(re.search(time_regex, t2).group(1))
        t1_val = float(re.search(time_regex, t1).group(1))

        #print t2_val
        #print t1_val

        t_out = t2_val - t1_val #measured in secs

        #t_out is the time offset between two subsequent samples
        if (t_out < 0): 
          t_out = t_out + 1
        #print t_out
      
        time_list.append(t_out)
        #print(("Time offset is: %f") % (t_out))

      if (str_array[2] != "N/A" and str_array[3] != "N/A" and \
        str_array[4] != "N/A" and str_array[2] != "IMU A1"):


        #Scale raw to get correct units in m/s^2
        g_const = 512            #g is the constant for gravity: 500 (measured in g?)
        gravity = -9.80665

        ax = float(str_array[2])  #x-axis (horizontal direction 1)
        ax = (ax/g_const)*gravity
        ay = float(str_array[3])  #y-axis, affected by gravity (vertical)
        ay = (ay/g_const)*gravity
        az = float(str_array[4])  #z-axis (horizontal direction 2)
        az = (az/g_const)*gravity

        #print(("ax: %f") % ax) 
        #print(("ay: %f") % ay)
        #print(("az: %f") % az)
        

        #Calculate the magnitude of acceleration from all three axes:
        a_mag = math.sqrt(ax**2 + ay**2 + az**2)

        #print("Acceleration a_mag is: %f") % a_mag

        #Double integrate aA to get approximate distance b/w wave trough and crest
        aA = a_mag + gravity #aA is the approximated vertical acceleration

        #print("Acceleration aA is: %f") % aA

        acc_list.append(aA)


    #Reset t1 and t2 after t_out is calculated
    t1 = t2
    t2 = 0

#----------Here, after both lists created----------
#Now, calculate wave heights between peaks and valleys.

if len(time_list) != len(acc_list):
  print("Error: Lengths of time_list and acc_list don't match!")
  #print len(time_list)
  #print len(acc_list)

else:
  #Initializations:
  a0 = 0
  v0 = 0
  d0 = 0

  i = 2            #start initialization at 2
  minNotFound = 1  #boolean
  numWaves = 0
  waveHeight = 0
  waveFreq = 0
  total_WH = 0
  total_WF = 0

  max_wi = 0  #index of local max wavepoint
  min_wi = 0  #index of local min wavepoint

  wave_pi = 0 #time of wave period
  total_wave_pi = 0

  #-------Setting the threshold------------
  threshold = 0.05  #not sure yet what to initalize threshold to

  end = len(acc_list)

  while(i < (end - 3)):
    a_prev2 = float(acc_list[i-2])
    a_prev1 = float(acc_list[i-1])
    a_this = float(acc_list[i])
    a_next1 = float(acc_list[i+1])
    a_next2 = float(acc_list[i+2])

    #Check if a_this is a max point
    if (a_prev1 > a_prev2 + threshold and a_this > a_prev1 + threshold \
      and a_next1 > a_this + threshold and a_next2 > a_this + threshold):

      max_wi = i
 
      #Do calculations until a new min is found 
      while (minNotFound and i < (end - 3)):
        t = time_list[i]
        #t = t_out
        a_new = acc_list[i] 
        v_new = (a_new*t) + v0
        d_new = (0.5*a_new*(t**2)) + v_new*t + d0 
    
        wave_pi = time_list[i+1] + wave_pi    
 
        #print "Looking for a min" 
        #print a_prev2
        #print a_prev1
        #print a_this
        #print a_next1
        #print a_next2

        #Check for next min point
        if (a_prev1 <  a_prev2 - threshold and a_this < a_prev1 - threshold \
          and a_this < a_next1 - threshold and a_next1 < a_next2 - threshold):

          #print("Found a new min")

          minNotFound = 0  #min point has been found at acc_list[i]
          min_wi = i

          t = time_list[i]
          #t = t_out
          a_new = acc_list[i] 
          v_new = (a_new*t) + v0
          d_new = (0.5*a_new*(t**2)) + v_new*t + d0 
          wave_pi = time_list[i] + wave_pi    

          #Don't count heights greater than 20m (unreasonable)
          # or periods greater than 30s
          if (abs(d_new) < 20 and 2*wave_pi < 30):
            numWaves = numWaves + 1
            waveHeight = abs(d_new)
            total_WH = total_WH + waveHeight

            if (wave_pi != 0):
              wave_pi = 2*wave_pi
              waveFreq = 1/(wave_pi) 
              total_wave_pi = total_wave_pi + 2*wave_pi
              print "The wave height is %f, wave frequency is %f, period: %f." \
                % (waveHeight, waveFreq, wave_pi)
              total_WF = total_WF + waveFreq

        #Set all parameters for next sample (same wave)
        a0 = a_new
        v0 = v_new
        d0 = d_new

        i = i + 1 #Increment i for while(minNotFound) loop
        a_prev2 = float(acc_list[i-2])
        a_prev1 = float(acc_list[i-1])
        a_this = float(acc_list[i])
        a_next1 = float(acc_list[i+1])
        a_next2 = float(acc_list[i+2])

    #Reset after every max point - calculating new wave height and frequency:
    a0 = 0
    v0 = 0
    d0 = 0

    minNotFound = 1
    waveHeight = 0
    waveFreq = 0

    max_wi = 0  #index of local max wavepoint
    min_wi = 0  #index of local min wavepoint
    wave_pi = 0 #time of wave period

    i = i + 1   #Increment i for while(i < end) loop

  #At the end of the .CSV data file, return results:
  if numWaves == 0:
    print("Error! numWaves = 0")
  else:
    avg_WH_m = total_WH/numWaves
    avg_WP = total_wave_pi/numWaves
    avg_WF = total_WF/numWaves
    #print ("avg_WP: %f")%avg_WP
    #print ("avg_WF: %f")%avg_WF
    #print ("1/avg_WP = avg_WF?: %f ?= %f")%(1/avg_WP, avg_WF)

    #if (avg_WP == 0):
    #  avg_WF = avg_WF
    #else:
    #  avg_WF = 1/avg_WP

    total_time_secs = sum(time_list)
    total_time_mins= total_time_secs/60 

    print("\n") 
    print("Algorithm Successful.")
    print("Using a threshold of %f:" % threshold)
    print("The total number of waves measured this session was: %d." % numWaves)
    print("The total time for this session was: %f secs (or %f mins)." \
      %(total_time_secs, total_time_mins))
    print("Calculated Average Wave Height as: %f m." % avg_WH_m) 
    print("Calculated Average Wave Period as: %f s." % avg_WP) 
    print("Calculated Average Wave Frequency as: %f Hz." % (1/avg_WP)) 
    #print "Calculated Average Wave Frequency as: %f Hz." % avg_WF
# Out:
# Running WaveStats Algorithm:
# The wave height is 0.800069, wave frequency is 0.132732, period: 7.534000.
# The wave height is 1.906432, wave frequency is 0.059242, period: 16.880000.
# The wave height is 1.490262, wave frequency is 0.101771, period: 9.826000.
# The wave height is 0.344228, wave frequency is 0.295858, period: 3.380000.
# The wave height is 0.788873, wave frequency is 0.113662, period: 8.798000.
# The wave height is 2.193969, wave frequency is 0.166334, period: 6.012000.
# The wave height is 0.048047, wave frequency is 0.318878, period: 3.136000.
# The wave height is 0.200302, wave frequency is 0.159898, period: 6.254000.
# The wave height is 0.377258, wave frequency is 0.131614, period: 7.598000.
# The wave height is 0.315579, wave frequency is 0.110889, period: 9.018000.
# The wave height is 0.198715, wave frequency is 0.250878, period: 3.986000.
# The wave height is 3.530283, wave frequency is 0.220556, period: 4.534000.
# The wave height is 0.055411, wave frequency is 0.181225, period: 5.518000.
# The wave height is 1.887604, wave frequency is 0.065963, period: 15.160000.
# The wave height is 1.274215, wave frequency is 0.109004, period: 9.174000.
# The wave height is 4.446588, wave frequency is 0.081011, period: 12.344000.
# The wave height is 1.269654, wave frequency is 0.119389, period: 8.376000.
# The wave height is 0.065064, wave frequency is 0.256805, period: 3.894000.
# The wave height is 0.172506, wave frequency is 0.332005, period: 3.012000.
# The wave height is 0.307038, wave frequency is 0.356633, period: 2.804000.
# The wave height is 0.168361, wave frequency is 0.357654, period: 2.796000.
# The wave height is 0.045446, wave frequency is 0.256016, period: 3.906000.
# The wave height is 0.229256, wave frequency is 0.180701, period: 5.534000.
# The wave height is 12.905746, wave frequency is 0.042783, period: 23.374000.
# The wave height is 0.066539, wave frequency is 0.248139, period: 4.030000.
# The wave height is 0.094849, wave frequency is 0.453721, period: 2.204000.
# The wave height is 0.146640, wave frequency is 0.332005, period: 3.012000.
# The wave height is 0.250684, wave frequency is 0.331785, period: 3.014000.
# The wave height is 0.340591, wave frequency is 0.331126, period: 3.020000.
# The wave height is 0.128919, wave frequency is 0.249377, period: 4.010000.
# The wave height is 0.005202, wave frequency is 0.398089, period: 2.512000.
# The wave height is 0.083922, wave frequency is 0.155618, period: 6.426000.
# The wave height is 0.242885, wave frequency is 0.198965, period: 5.026000.
# The wave height is 13.763728, wave frequency is 0.042359, period: 23.608000.
# The wave height is 0.729880, wave frequency is 0.285388, period: 3.504000.
# The wave height is 0.952078, wave frequency is 0.161394, period: 6.196000.
# The wave height is 0.127216, wave frequency is 0.146628, period: 6.820000.
# The wave height is 0.378274, wave frequency is 0.127584, period: 7.838000.
# The wave height is 3.582904, wave frequency is 0.061147, period: 16.354000.
# The wave height is 3.513007, wave frequency is 0.102754, period: 9.732000.
# The wave height is 1.247292, wave frequency is 0.099030, period: 10.098000.
# The wave height is 0.036534, wave frequency is 0.414938, period: 2.410000.
# The wave height is 0.208212, wave frequency is 0.243191, period: 4.112000.
# The wave height is 0.267246, wave frequency is 0.220653, period: 4.532000.
# The wave height is 0.527617, wave frequency is 0.225734, period: 4.430000.
# The wave height is 2.609102, wave frequency is 0.071429, period: 14.000000.
# The wave height is 0.173218, wave frequency is 0.359454, period: 2.782000.
# The wave height is 0.255791, wave frequency is 0.354862, period: 2.818000.
# The wave height is 0.405360, wave frequency is 0.153846, period: 6.500000.
# The wave height is 0.414882, wave frequency is 0.282965, period: 3.534000.
# The wave height is 0.766689, wave frequency is 0.170707, period: 5.858000.
# The wave height is 0.336325, wave frequency is 0.283930, period: 3.522000.
# The wave height is 3.067106, wave frequency is 0.199124, period: 5.022000.
# The wave height is 0.974582, wave frequency is 0.054206, period: 18.448000.
# The wave height is 0.326748, wave frequency is 0.314861, period: 3.176000.
# The wave height is 1.029762, wave frequency is 0.148500, period: 6.734000.
# The wave height is 0.144532, wave frequency is 0.355366, period: 2.814000.
# The wave height is 0.094011, wave frequency is 0.365497, period: 2.736000.
# The wave height is 1.031824, wave frequency is 0.138543, period: 7.218000.
# The wave height is 0.135945, wave frequency is 0.331785, period: 3.014000.
# The wave height is 0.539967, wave frequency is 0.289519, period: 3.454000.
# The wave height is 1.050567, wave frequency is 0.124409, period: 8.038000.
# The wave height is 0.047689, wave frequency is 0.356633, period: 2.804000.
# The wave height is 0.159252, wave frequency is 0.414594, period: 2.412000.
# The wave height is 0.056981, wave frequency is 0.496032, period: 2.016000.
# The wave height is 1.079206, wave frequency is 0.036185, period: 27.636000.
# The wave height is 2.313749, wave frequency is 0.283768, period: 3.524000.
# The wave height is 6.767135, wave frequency is 0.055648, period: 17.970000.
# The wave height is 0.492352, wave frequency is 0.140766, period: 7.104000.
# The wave height is 0.169322, wave frequency is 0.285714, period: 3.500000.
# The wave height is 0.191020, wave frequency is 0.248880, period: 4.018000.
# The wave height is 0.056161, wave frequency is 0.364964, period: 2.740000.
# The wave height is 1.807683, wave frequency is 0.102103, period: 9.794000.
# The wave height is 0.109580, wave frequency is 0.239349, period: 4.178000.
# The wave height is 0.284467, wave frequency is 0.191791, period: 5.214000.
# The wave height is 0.113816, wave frequency is 0.356888, period: 2.802000.
# The wave height is 0.174247, wave frequency is 0.166445, period: 6.008000.
# The wave height is 0.180149, wave frequency is 0.530223, period: 1.886000.
# The wave height is 0.358263, wave frequency is 0.260960, period: 3.832000.
# The wave height is 0.016075, wave frequency is 0.421941, period: 2.370000.
# The wave height is 0.193687, wave frequency is 0.199203, period: 5.020000.
# The wave height is 0.168645, wave frequency is 0.414938, period: 2.410000.
# The wave height is 0.213258, wave frequency is 0.277778, period: 3.600000.
# The wave height is 1.680258, wave frequency is 0.236967, period: 4.220000.
# The wave height is 0.221096, wave frequency is 0.077077, period: 12.974000.
# The wave height is 8.001343, wave frequency is 0.046878, period: 21.332000.
# The wave height is 0.597570, wave frequency is 0.332668, period: 3.006000.
# The wave height is 0.706089, wave frequency is 0.187758, period: 5.326000.
# The wave height is 0.469158, wave frequency is 0.205931, period: 4.856000.
# The wave height is 0.369092, wave frequency is 0.181094, period: 5.522000.
# The wave height is 0.828404, wave frequency is 0.142167, period: 7.034000.
# The wave height is 2.400938, wave frequency is 0.080425, period: 12.434000.
# The wave height is 1.904457, wave frequency is 0.080038, period: 12.494000.
# The wave height is 13.424193, wave frequency is 0.053545, period: 18.676000.
# The wave height is 0.168667, wave frequency is 0.199521, period: 5.012000.
# The wave height is 0.042089, wave frequency is 0.339443, period: 2.946000.
# The wave height is 0.188156, wave frequency is 0.248633, period: 4.022000.
# The wave height is 0.055037, wave frequency is 0.166834, period: 5.994000.
# The wave height is 0.672947, wave frequency is 0.333333, period: 3.000000.
# The wave height is 0.096717, wave frequency is 0.331785, period: 3.014000.
# The wave height is 0.149649, wave frequency is 0.249377, period: 4.010000.
# The wave height is 3.018302, wave frequency is 0.062050, period: 16.116000.
# The wave height is 0.616973, wave frequency is 0.148368, period: 6.740000.
# The wave height is 0.136480, wave frequency is 0.413907, period: 2.416000.
# The wave height is 0.578689, wave frequency is 0.248139, period: 4.030000.
# The wave height is 0.072458, wave frequency is 0.115447, period: 8.662000.
# The wave height is 0.572252, wave frequency is 0.085106, period: 11.750000.
# The wave height is 0.091310, wave frequency is 0.155231, period: 6.442000.
# The wave height is 0.233425, wave frequency is 0.130822, period: 7.644000.
# The wave height is 0.431613, wave frequency is 0.295159, period: 3.388000.
# The wave height is 0.045441, wave frequency is 0.228728, period: 4.372000.
# The wave height is 2.640904, wave frequency is 0.043664, period: 22.902000.
# The wave height is 0.886604, wave frequency is 0.157332, period: 6.356000.
# The wave height is 0.103530, wave frequency is 0.207125, period: 4.828000.
# The wave height is 0.328876, wave frequency is 0.133833, period: 7.472000.
# The wave height is 0.413713, wave frequency is 0.250125, period: 3.998000.
# The wave height is 0.156872, wave frequency is 0.284252, period: 3.518000.
# The wave height is 0.073233, wave frequency is 0.285225, period: 3.506000.
# The wave height is 0.481112, wave frequency is 0.135612, period: 7.374000.
# The wave height is 0.072861, wave frequency is 0.256542, period: 3.898000.
# The wave height is 0.619766, wave frequency is 0.124626, period: 8.024000.
# The wave height is 0.285668, wave frequency is 0.207383, period: 4.822000.
# The wave height is 0.000069, wave frequency is 0.496032, period: 2.016000.
# The wave height is 0.998567, wave frequency is 0.138045, period: 7.244000.
# The wave height is 0.408964, wave frequency is 0.283607, period: 3.526000.
# The wave height is 0.263295, wave frequency is 0.499500, period: 2.002000.
# The wave height is 0.072861, wave frequency is 0.497018, period: 2.012000.
# The wave height is 0.078270, wave frequency is 0.417362, period: 2.396000.
# The wave height is 0.025940, wave frequency is 0.414250, period: 2.414000.
# The wave height is 0.194472, wave frequency is 0.249501, period: 4.008000.
# The wave height is 0.783581, wave frequency is 0.169952, period: 5.884000.
# The wave height is 0.046954, wave frequency is 0.497018, period: 2.012000.
# The wave height is 0.826868, wave frequency is 0.138389, period: 7.226000.
# The wave height is 3.306075, wave frequency is 0.107158, period: 9.332000.
# The wave height is 0.167771, wave frequency is 0.332447, period: 3.008000.
# The wave height is 1.779669, wave frequency is 0.199283, period: 5.018000.
# The wave height is 1.233979, wave frequency is 0.118991, period: 8.404000.
# The wave height is 0.225655, wave frequency is 0.152393, period: 6.562000.
# The wave height is 13.641838, wave frequency is 0.038058, period: 26.276000.
# The wave height is 0.467087, wave frequency is 0.248880, period: 4.018000.
# The wave height is 13.051782, wave frequency is 0.088889, period: 11.250000.
# The wave height is 0.615899, wave frequency is 0.181291, period: 5.516000.
# The wave height is 2.093355, wave frequency is 0.054777, period: 18.256000.
# The wave height is 0.111389, wave frequency is 0.166003, period: 6.024000.
# The wave height is 0.017525, wave frequency is 0.331126, period: 3.020000.
# The wave height is 0.097516, wave frequency is 0.153610, period: 6.510000.
# The wave height is 0.170724, wave frequency is 0.284091, period: 3.520000.
# The wave height is 3.180747, wave frequency is 0.067105, period: 14.902000.
# The wave height is 0.472740, wave frequency is 0.148060, period: 6.754000.
# The wave height is 0.278420, wave frequency is 0.188395, period: 5.308000.
# The wave height is 0.801737, wave frequency is 0.226040, period: 4.424000.
# The wave height is 0.487008, wave frequency is 0.131648, period: 7.596000.
# The wave height is 0.121236, wave frequency is 0.242718, period: 4.120000.
# The wave height is 1.149144, wave frequency is 0.118850, period: 8.414000.
# The wave height is 0.223738, wave frequency is 0.242954, period: 4.116000.
# The wave height is 0.000373, wave frequency is 0.354610, period: 2.820000.
# The wave height is 0.624311, wave frequency is 0.197863, period: 5.054000.
# The wave height is 0.229620, wave frequency is 0.146327, period: 6.834000.
# The wave height is 3.809200, wave frequency is 0.056915, period: 17.570000.
# The wave height is 2.295509, wave frequency is 0.106883, period: 9.356000.
# The wave height is 0.319558, wave frequency is 0.346741, period: 2.884000.
# The wave height is 0.191526, wave frequency is 0.225836, period: 4.428000.
# The wave height is 0.221198, wave frequency is 0.177494, period: 5.634000.
# The wave height is 0.833510, wave frequency is 0.207987, period: 4.808000.
# The wave height is 0.254331, wave frequency is 0.354108, period: 2.824000.
# The wave height is 0.272271, wave frequency is 0.310752, period: 3.218000.
# The wave height is 0.018939, wave frequency is 0.208681, period: 4.792000.
# The wave height is 0.691801, wave frequency is 0.208247, period: 4.802000.
# The wave height is 0.198676, wave frequency is 0.130993, period: 7.634000.
# The wave height is 0.067845, wave frequency is 0.496032, period: 2.016000.
# The wave height is 12.725478, wave frequency is 0.045257, period: 22.096000.
# The wave height is 0.514825, wave frequency is 0.134300, period: 7.446000.
# The wave height is 0.316945, wave frequency is 0.276243, period: 3.620000.
# The wave height is 0.120939, wave frequency is 0.335796, period: 2.978000.
# The wave height is 0.340691, wave frequency is 0.233754, period: 4.278000.
# The wave height is 2.441832, wave frequency is 0.249004, period: 4.016000.
# The wave height is 12.810820, wave frequency is 0.095274, period: 10.496000.
# The wave height is 1.878075, wave frequency is 0.050813, period: 19.680000.
# The wave height is 1.906520, wave frequency is 0.075896, period: 13.176000.
# The wave height is 0.003613, wave frequency is 0.249004, period: 4.016000.
# The wave height is 0.084383, wave frequency is 0.286369, period: 3.492000.
# The wave height is 0.014128, wave frequency is 0.488281, period: 2.048000.
# The wave height is 13.533357, wave frequency is 0.041985, period: 23.818000.
# The wave height is 0.458399, wave frequency is 0.331565, period: 3.016000.
# The wave height is 10.845551, wave frequency is 0.132100, period: 7.570000.
# The wave height is 3.490964, wave frequency is 0.149745, period: 6.678000.
# The wave height is 9.415751, wave frequency is 0.035122, period: 28.472000.
# The wave height is 0.911665, wave frequency is 0.156740, period: 6.380000.
# The wave height is 1.624455, wave frequency is 0.221828, period: 4.508000.
# The wave height is 2.779633, wave frequency is 0.124906, period: 8.006000.
# The wave height is 7.608949, wave frequency is 0.099602, period: 10.040000.
# The wave height is 1.381465, wave frequency is 0.125913, period: 7.942000.
# The wave height is 0.750449, wave frequency is 0.398089, period: 2.512000.
# The wave height is 0.234801, wave frequency is 0.397456, period: 2.516000.
# The wave height is 1.689518, wave frequency is 0.270856, period: 3.692000.
# The wave height is 11.207768, wave frequency is 0.084147, period: 11.884000.
# The wave height is 6.869502, wave frequency is 0.046279, period: 21.608000.
# The wave height is 7.439451, wave frequency is 0.071124, period: 14.060000.
# The wave height is 0.832975, wave frequency is 0.104976, period: 9.526000.
# The wave height is 1.154935, wave frequency is 0.333111, period: 3.002000.
# The wave height is 8.383888, wave frequency is 0.099562, period: 10.044000.
# The wave height is 0.228923, wave frequency is 0.284252, period: 3.518000.
# The wave height is 0.628811, wave frequency is 0.130174, period: 7.682000.
# The wave height is 2.172392, wave frequency is 0.142126, period: 7.036000.
# The wave height is 10.932588, wave frequency is 0.087642, period: 11.410000.
# The wave height is 3.472431, wave frequency is 0.283930, period: 3.522000.
# The wave height is 5.557249, wave frequency is 0.178253, period: 5.610000.
# The wave height is 15.578594, wave frequency is 0.049305, period: 20.282000.
# The wave height is 11.849388, wave frequency is 0.199601, period: 5.010000.
# The wave height is 1.742840, wave frequency is 0.283607, period: 3.526000.
# The wave height is 12.568552, wave frequency is 0.038539, period: 25.948000.
# The wave height is 4.060570, wave frequency is 0.111807, period: 8.944000.
# The wave height is 5.884788, wave frequency is 0.141084, period: 7.088000.
# The wave height is 0.685319, wave frequency is 0.233973, period: 4.274000.
# The wave height is 2.069995, wave frequency is 0.101235, period: 9.878000.
# The wave height is 3.369712, wave frequency is 0.284252, period: 3.518000.
# The wave height is 8.648764, wave frequency is 0.102249, period: 9.780000.
# The wave height is 0.448626, wave frequency is 0.413907, period: 2.416000.
# The wave height is 10.569041, wave frequency is 0.091191, period: 10.966000.
# The wave height is 0.104885, wave frequency is 0.158730, period: 6.300000.
# The wave height is 2.530189, wave frequency is 0.331565, period: 3.016000.
# The wave height is 1.482239, wave frequency is 0.400962, period: 2.494000.
# The wave height is 3.951154, wave frequency is 0.117897, period: 8.482000.
# The wave height is 1.435781, wave frequency is 0.160462, period: 6.232000.
# The wave height is 0.688404, wave frequency is 0.332889, period: 3.004000.
# The wave height is 18.080480, wave frequency is 0.069813, period: 14.324000.
# The wave height is 10.087122, wave frequency is 0.100341, period: 9.966000.
# The wave height is 0.550697, wave frequency is 0.330907, period: 3.022000.
# The wave height is 4.890012, wave frequency is 0.221729, period: 4.510000.
# The wave height is 16.779201, wave frequency is 0.104232, period: 9.594000.
# The wave height is 0.388134, wave frequency is 0.154083, period: 6.490000.
# The wave height is 14.506776, wave frequency is 0.072474, period: 13.798000.
# The wave height is 2.648227, wave frequency is 0.091996, period: 10.870000.
# The wave height is 7.197672, wave frequency is 0.142572, period: 7.014000.
# The wave height is 0.479137, wave frequency is 0.132310, period: 7.558000.
# The wave height is 18.457974, wave frequency is 0.123793, period: 8.078000.
# The wave height is 2.009365, wave frequency is 0.221435, period: 4.516000.
# The wave height is 1.183991, wave frequency is 0.082129, period: 12.176000.
# The wave height is 1.619865, wave frequency is 0.084588, period: 11.822000.
# The wave height is 8.047137, wave frequency is 0.111185, period: 8.994000.
# The wave height is 16.031297, wave frequency is 0.078976, period: 12.662000.
# The wave height is 6.597482, wave frequency is 0.203500, period: 4.914000.
# The wave height is 10.971353, wave frequency is 0.124471, period: 8.034000.
# The wave height is 0.610374, wave frequency is 0.311526, period: 3.210000.
# The wave height is 0.174604, wave frequency is 0.265252, period: 3.770000.
# The wave height is 0.397647, wave frequency is 0.404531, period: 2.472000.
# The wave height is 2.246950, wave frequency is 0.182882, period: 5.468000.
# The wave height is 14.647656, wave frequency is 0.072327, period: 13.826000.
# The wave height is 5.091810, wave frequency is 0.297089, period: 3.366000.
# The wave height is 2.421154, wave frequency is 0.320924, period: 3.116000.
# The wave height is 1.170540, wave frequency is 0.331345, period: 3.018000.
# The wave height is 6.768683, wave frequency is 0.221729, period: 4.510000.
# The wave height is 0.875378, wave frequency is 0.153280, period: 6.524000.
# The wave height is 2.064627, wave frequency is 0.284738, period: 3.512000.
# The wave height is 1.107284, wave frequency is 0.221631, period: 4.512000.
# The wave height is 10.406901, wave frequency is 0.076464, period: 13.078000.
# The wave height is 1.751368, wave frequency is 0.176491, period: 5.666000.
# The wave height is 10.685697, wave frequency is 0.189466, period: 5.278000.
# The wave height is 0.374685, wave frequency is 0.331345, period: 3.018000.
# The wave height is 1.886527, wave frequency is 0.397141, period: 2.518000.
# The wave height is 1.778663, wave frequency is 0.108295, period: 9.234000.
# The wave height is 1.544150, wave frequency is 0.118259, period: 8.456000.
# The wave height is 4.819530, wave frequency is 0.088230, period: 11.334000.
# The wave height is 12.218570, wave frequency is 0.047001, period: 21.276000.
#
#
# Algorithm Successful.
# Using a threshold of 0.050000:
# The total number of waves measured this session was: 264.
# The total time for this session was: 5971.172000 secs (or 99.519533 mins).
# Calculated Average Wave Height as: 2.459415 m.
# Calculated Average Wave Period as: 14.213561 s.
# Calculated Average Wave Frequency as: 0.070355 Hz.

# %%
#Purisa Jasmine Simmons
#July 12, 2018
#Estimating wave statistics from IMU data.
#Version 1: Focuses on data collected from accelerometer.
#Using this paper as a guide: http://essay.utwente.nl/59198/1/scriptie_J_Kuperus.pdf

#Overview of Algorithm:
#1. Create two arrays: time_list has time offsets and acc_list has accelerations.
#2. Find local maximums and local minimums, using a threshold.
#3. Estimate wave height via double integration of acceleration between
#   a peak and the subsequent valley.
#4. Return the average wave height for that surf session. 
#5. Return the average wave frequency.  


#Data Units:
#acceleration is measured in g, 500a = 1g = -9.81m/s^2
#velocity measured in m/s
#distance measured in m
#time measured in seconds

import math
import re

#Need to do peak-picking before algorithm runs:
#1. Read through file, save all times and accelerations:
print('Running WaveStats Algorithm:')

#Reading data from filename_r
filename_r = "Motion_14637.CSV"
read_file = open(filename_r, "r")

#File that gets written to:
write_file = open("WaveStatsOut.txt", "w")

#Initialize lists
t1 = 0 
t2 = 0
time_list = []  #list of time offsets; t_out = current_time - prev_time 
acc_list = []   #list of estimated accelerations

with open(filename_r, 'r') as f: 
  for line in f:
    #print line     #helps with debugging
    str_array = line.split(',')  #separates each line into an array on commas

    #-------Calculating Time Offset--------#
    if str_array[0] == "UTC":
      t1 = 0
      t2 = 0
      time_list.append(0)  #initialize time_list with 0

    else:
      t2 = str_array[0]

      if (t2 != 0 and t1 != 0 and str_array[2] != "N/A"):
        time_regex = r"(\.\d+)" #regex to get the part of time that we care about
        t2_val = float(re.search(time_regex, t2).group(1))
        t1_val = float(re.search(time_regex, t1).group(1))

        #print t2_val
        #print t1_val

        t_out = t2_val - t1_val #measured in secs

        #t_out is the time offset between two subsequent samples
        if (t_out < 0): 
          t_out = t_out + 1
        #print t_out
      
        time_list.append(t_out)
        #print(("Time offset is: %f") % (t_out))

      if (str_array[2] != "N/A" and str_array[3] != "N/A" and \
        str_array[4] != "N/A" and str_array[2] != "IMU A1"):


        #Scale raw to get correct units in m/s^2
        g_const = 512            #g is the constant for gravity: 500 (measured in g?)
        gravity = -9.80665

        ax = float(str_array[2])  #x-axis (horizontal direction 1)
        ax = (ax/g_const)*gravity
        ay = float(str_array[3])  #y-axis, affected by gravity (vertical)
        ay = (ay/g_const)*gravity
        az = float(str_array[4])  #z-axis (horizontal direction 2)
        az = (az/g_const)*gravity

        #print(("ax: %f") % ax) 
        #print(("ay: %f") % ay)
        #print(("az: %f") % az)
        

        #Calculate the magnitude of acceleration from all three axes:
        a_mag = math.sqrt(ax**2 + ay**2 + az**2)

        #print("Acceleration a_mag is: %f") % a_mag

        #Double integrate aA to get approximate distance b/w wave trough and crest
        aA = a_mag + gravity #aA is the approximated vertical acceleration

        #print("Acceleration aA is: %f") % aA

        acc_list.append(aA)


    #Reset t1 and t2 after t_out is calculated
    t1 = t2
    t2 = 0

#----------Here, after both lists created----------
#Now, calculate wave heights between peaks and valleys.

if len(time_list) != len(acc_list):
  print("Error: Lengths of time_list and acc_list don't match!")
  #print len(time_list)
  #print len(acc_list)

else:
  #Initializations:
  a0 = 0
  v0 = 0
  d0 = 0

  i = 2            #start initialization at 2
  minNotFound = 1  #boolean
  numWaves = 0
  waveHeight = 0
  waveFreq = 0
  total_WH = 0
  total_WF = 0

  max_wi = 0  #index of local max wavepoint
  min_wi = 0  #index of local min wavepoint

  wave_pi = 0 #time of wave period
  total_wave_pi = 0

  #-------Setting the threshold------------
  threshold = 0.05  #not sure yet what to initalize threshold to

  end = len(acc_list)

  while(i < (end - 3)):
    a_prev2 = float(acc_list[i-2])
    a_prev1 = float(acc_list[i-1])
    a_this = float(acc_list[i])
    a_next1 = float(acc_list[i+1])
    a_next2 = float(acc_list[i+2])

    #Check if a_this is a max point
    if (a_prev1 > a_prev2 + threshold and a_this > a_prev1 + threshold \
      and a_next1 > a_this + threshold and a_next2 > a_this + threshold):

      max_wi = i
 
      #Do calculations until a new min is found 
      while (minNotFound and i < (end - 3)):
        t = time_list[i]
        #t = t_out
        a_new = acc_list[i] 
        v_new = (a_new*t) + v0
        d_new = (0.5*a_new*(t**2)) + v_new*t + d0 
    
        wave_pi = time_list[i+1] + wave_pi    
 
        #print "Looking for a min" 
        #print a_prev2
        #print a_prev1
        #print a_this
        #print a_next1
        #print a_next2

        #Check for next min point
        if (a_prev1 <  a_prev2 - threshold and a_this < a_prev1 - threshold \
          and a_this < a_next1 - threshold and a_next1 < a_next2 - threshold):

          #print("Found a new min")

          minNotFound = 0  #min point has been found at acc_list[i]
          min_wi = i

          t = time_list[i]
          #t = t_out
          a_new = acc_list[i] 
          v_new = (a_new*t) + v0
          d_new = (0.5*a_new*(t**2)) + v_new*t + d0 
          wave_pi = time_list[i] + wave_pi    

          #Don't count heights greater than 20m (unreasonable)
          # or periods greater than 30s
          if (abs(d_new) < 20 and 2*wave_pi < 30):
            numWaves = numWaves + 1
            waveHeight = abs(d_new)
            total_WH = total_WH + waveHeight

            if (wave_pi != 0):
              wave_pi = 2*wave_pi
              waveFreq = 1/(wave_pi) 
              total_wave_pi = total_wave_pi + wave_pi
              print "The wave height is %f, wave frequency is %f, period: %f." \
                % (waveHeight, waveFreq, wave_pi)
              total_WF = total_WF + waveFreq

        #Set all parameters for next sample (same wave)
        a0 = a_new
        v0 = v_new
        d0 = d_new

        i = i + 1 #Increment i for while(minNotFound) loop
        a_prev2 = float(acc_list[i-2])
        a_prev1 = float(acc_list[i-1])
        a_this = float(acc_list[i])
        a_next1 = float(acc_list[i+1])
        a_next2 = float(acc_list[i+2])

    #Reset after every max point - calculating new wave height and frequency:
    a0 = 0
    v0 = 0
    d0 = 0

    minNotFound = 1
    waveHeight = 0
    waveFreq = 0

    max_wi = 0  #index of local max wavepoint
    min_wi = 0  #index of local min wavepoint
    wave_pi = 0 #time of wave period

    i = i + 1   #Increment i for while(i < end) loop

  #At the end of the .CSV data file, return results:
  if numWaves == 0:
    print("Error! numWaves = 0")
  else:
    avg_WH_m = total_WH/numWaves
    avg_WP = total_wave_pi/numWaves
    avg_WF = total_WF/numWaves
    #print ("avg_WP: %f")%avg_WP
    #print ("avg_WF: %f")%avg_WF
    #print ("1/avg_WP = avg_WF?: %f ?= %f")%(1/avg_WP, avg_WF)

    #if (avg_WP == 0):
    #  avg_WF = avg_WF
    #else:
    #  avg_WF = 1/avg_WP

    total_time_secs = sum(time_list)
    total_time_mins= total_time_secs/60 

    print("\n") 
    print("Algorithm Successful.")
    print("Using a threshold of %f:" % threshold)
    print("The total number of waves measured this session was: %d." % numWaves)
    print("The total time for this session was: %f secs (or %f mins)." \
      %(total_time_secs, total_time_mins))
    print("Calculated Average Wave Height as: %f m." % avg_WH_m) 
    print("Calculated Average Wave Period as: %f s." % avg_WP) 
    print("Calculated Average Wave Frequency as: %f Hz." % (1/avg_WP)) 
    #print "Calculated Average Wave Frequency as: %f Hz." % avg_WF
# Out:
# Running WaveStats Algorithm:
# The wave height is 0.861328, wave frequency is 0.114705, period: 8.718000.
# The wave height is 0.299967, wave frequency is 0.330907, period: 3.022000.
# The wave height is 0.779479, wave frequency is 0.355114, period: 2.816000.
# The wave height is 3.581347, wave frequency is 0.087781, period: 11.392000.
# The wave height is 1.820885, wave frequency is 0.331565, period: 3.016000.
# The wave height is 0.226040, wave frequency is 0.331126, period: 3.020000.
# The wave height is 2.308247, wave frequency is 0.073196, period: 13.662000.
# The wave height is 0.101756, wave frequency is 0.240385, period: 4.160000.
# The wave height is 0.083342, wave frequency is 0.220556, period: 4.534000.
# The wave height is 0.009233, wave frequency is 0.332889, period: 3.004000.
# The wave height is 0.164510, wave frequency is 0.248633, period: 4.022000.
# The wave height is 0.234394, wave frequency is 0.353357, period: 2.830000.
# The wave height is 0.473170, wave frequency is 0.283126, period: 3.532000.
# The wave height is 0.164731, wave frequency is 0.251889, period: 3.970000.
# The wave height is 0.092770, wave frequency is 0.246548, period: 4.056000.
# The wave height is 0.190025, wave frequency is 0.255363, period: 3.916000.
# The wave height is 3.363382, wave frequency is 0.093493, period: 10.696000.
# The wave height is 0.249857, wave frequency is 0.181357, period: 5.514000.
# The wave height is 0.012392, wave frequency is 0.397141, period: 2.518000.
# The wave height is 0.145232, wave frequency is 0.248756, period: 4.020000.
# The wave height is 0.198206, wave frequency is 0.328947, period: 3.040000.
# The wave height is 0.211608, wave frequency is 0.331126, period: 3.020000.
# The wave height is 0.570364, wave frequency is 0.142491, period: 7.018000.
# The wave height is 1.491429, wave frequency is 0.110473, period: 9.052000.
# The wave height is 1.437626, wave frequency is 0.140607, period: 7.112000.
# The wave height is 4.074808, wave frequency is 0.078296, period: 12.772000.
# The wave height is 0.118159, wave frequency is 0.312110, period: 3.204000.
# The wave height is 0.372593, wave frequency is 0.271739, period: 3.680000.
# The wave height is 1.940141, wave frequency is 0.099721, period: 10.028000.
# The wave height is 0.062930, wave frequency is 0.495540, period: 2.018000.
# The wave height is 1.671080, wave frequency is 0.113097, period: 8.842000.
# The wave height is 2.277978, wave frequency is 0.112057, period: 8.924000.
# The wave height is 1.836216, wave frequency is 0.168634, period: 5.930000.
# The wave height is 0.138720, wave frequency is 0.199124, period: 5.022000.
# The wave height is 0.040835, wave frequency is 0.453309, period: 2.206000.
# The wave height is 2.030808, wave frequency is 0.100341, period: 9.966000.
# The wave height is 0.166361, wave frequency is 0.183554, period: 5.448000.
# The wave height is 0.096539, wave frequency is 0.264550, period: 3.780000.
# The wave height is 0.279594, wave frequency is 0.215703, period: 4.636000.
# The wave height is 0.385072, wave frequency is 0.154703, period: 6.464000.
# The wave height is 1.496517, wave frequency is 0.133583, period: 7.486000.
# The wave height is 3.726833, wave frequency is 0.090449, period: 11.056000.
# The wave height is 0.059381, wave frequency is 0.417362, period: 2.396000.
# The wave height is 0.119046, wave frequency is 0.414250, period: 2.414000.
# The wave height is 11.383352, wave frequency is 0.050317, period: 19.874000.
# The wave height is 0.228508, wave frequency is 0.141924, period: 7.046000.
# The wave height is 17.282803, wave frequency is 0.035920, period: 27.840000.
# The wave height is 2.268730, wave frequency is 0.250878, period: 3.986000.
# The wave height is 0.930658, wave frequency is 0.142126, period: 7.036000.
# The wave height is 0.298829, wave frequency is 0.270856, period: 3.692000.
# The wave height is 3.434124, wave frequency is 0.077954, period: 12.828000.
# The wave height is 0.347751, wave frequency is 0.142167, period: 7.034000.
# The wave height is 0.269642, wave frequency is 0.104690, period: 9.552000.
# The wave height is 0.019027, wave frequency is 0.413223, period: 2.420000.
# The wave height is 0.677599, wave frequency is 0.199521, period: 5.012000.
# The wave height is 0.110650, wave frequency is 0.331345, period: 3.018000.
# The wave height is 0.227992, wave frequency is 0.177873, period: 5.622000.
# The wave height is 13.159983, wave frequency is 0.048375, period: 20.672000.
# The wave height is 0.190139, wave frequency is 0.401929, period: 2.488000.
# The wave height is 0.022499, wave frequency is 0.495540, period: 2.018000.
# The wave height is 0.010705, wave frequency is 0.541126, period: 1.848000.
# The wave height is 0.110445, wave frequency is 0.356888, period: 2.802000.
# The wave height is 0.746966, wave frequency is 0.191644, period: 5.218000.
# The wave height is 4.305294, wave frequency is 0.059495, period: 16.808000.
# The wave height is 1.347280, wave frequency is 0.331345, period: 3.018000.
# The wave height is 6.906709, wave frequency is 0.099522, period: 10.048000.
# The wave height is 1.468610, wave frequency is 0.122760, period: 8.146000.
# The wave height is 0.000732, wave frequency is 0.400641, period: 2.496000.
# The wave height is 2.510574, wave frequency is 0.039623, period: 25.238000.
#
#
# Algorithm Successful.
# Using a threshold of 0.050000:
# The total number of waves measured this session was: 69.
# The total time for this session was: 901.869000 secs (or 15.031150 mins).
# Calculated Average Wave Height as: 1.568472 m.
# Calculated Average Wave Period as: 6.720174 s.
# Calculated Average Wave Frequency as: 0.148806 Hz.
